# %% [markdown]
# ##Bem-vindo a aula 4 de API em Python
#
# Na aula de hoje, vamos aos últimos tópicos desse Super Módulo.
#
# Nas aulas passadas aprendemos:
#
# - O que é API
# - O que é o FastAPI
# - Para que serve
# - Funções assíncronas
# - Performance do FastAPI comparado a outras tecnologias
# - SQLAlchemy
# - Estruturação do nosso projeto
# - Divisão de responsabilidades
#
# Todos esses tópicos e muito mais.

# %% [markdown]
# Na aula de hoje, veremos os últimos tópicos e irei passar alguns assuntos para vocês continuarem os estudos sobre API e desenvolvimento backend.

# %% [markdown]
# Como vimos na aula passada, temos um pequeno problema ainda nessa aplicação que construímos, o primeiro é que só temos acesso na nossa máquina e o segundo problema é o banco de dados que temos, que não é um banco de dados robusto para uma aplicação rodar normalmente.
#
# Então, na aula de hoje, faremos o famoso **_Deploy_**, isso consiste em deixar a nossa aplicação no ar, onde outras pessoas vão poder acessar e utilizar nossa aplicação onde tiverem acesso a internet.

# %% [markdown]
# Para aplicarmos isso, vamos utilizar um plataforma chamada **_Render_**, isso se deve ao fato de não precisarmos entrar mais afundo nos estudos de infraestrutura de software.
#
# Por isso, fiquem ligados, o render é uma ótima opção para fazer deploy das suas api's, mas, nem de longe a melhor plataforma para isso, temos outras plataformas pagas como a AWS, Oracle, Google GCP, Azure, Digital Ocean, que são muitos melhores e mais abertas para executarmos o deploy das nossas aplicações.
#
# Certo, professor, então por que não utilizamos essas?
#
# A resposta mais prática, é porque são cloud's pagas 🙂.

# %% [markdown]
# Para começarmos o processo de deploy, precisamos começar criando uma conta ou para quem já tiver conta, no GitHub.
#
# https://github.com/
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Depois de criarmos ou entrarmos na nossa conta, vamos acessar o site do **_render_**
#
# https://render.com/

# %% [markdown]
# Aqui, vamos conseguir logar apenas com a conta do GitHub e dessa maneira, quando subirmos um repositório pra lá, a plataforma vai enxergar a aplicação que queremos fazer o deploy.

# %% [markdown]
# Dessa forma, ao entrar na plataforma, vocês devem estar vendo uma tela parecida com essa.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Como foi visto mais acima, nossa aplicação tem um SQLite, ele não um banco apropriado para produção, por isso, vamos utilizar um banco de dados da própria plataforma, conhecido como postgres.
#
# Por que o Postgres?
#
# Nos diversos cursos que vemos na internet, o banco de dados mais utilizados normalmente é o MySQL, porém, ele é muito utilizado por conta da sua facilidade, por ter uma interface amigável e por ser um dos bancos de dados mais utilizados no mundo.
#
# Mas, atualmente, no mercado, o banco de dados mais utilizado de longe é o PostgreSQL, os dois seguem a mesma linguagem que é o SQL, mas o Postgres acaba sendo mais utilizado por ser completamente Open-source e por possuir diversas funcionalidades próprias.

# %% [markdown]
# Agora, dentro da plataforma, vamos ver como criar a nossa instância do postgres.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ao clicarmos em postgres, vamos ver uma tela dessa forma:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Os campos, vocês vão colocar os SEUS dados, não copiem do colega, escola um nome para o banco, para a instância e não esqueça de marcar o plano gratuito.

# %% [markdown]
# Feito isso, precisamos conectar subir nossa aplicação no Render, primeiro de tudo, precisamos dar dois passos para trás, pois, precisamos subir essa aplicação no GitHub.
#
# O primeiro passo é entrarmos na nossa conta, irmos em respositorios e depois em novo, lá vamos criar nosso repositório referente a esse projeto.

# %% [markdown]
# Logo depois de criarmos o nosso repositório, vamos ver que temos uma série de comandos git para subirmos o nosso projeto, podemos aplicar eles mesmo para executarmos isso.

# %% [markdown]
# Primeiro, vamos criar um arquivo na nossa aplicação chamado .gitignore e dentro desse arquivo vamos passar o seguinte
#
# .venv
# __pycache__

# %% [markdown]
# Feito isso, agora podemos voltar para a plataforma **render**.

# %% [markdown]
# Agora, no mesmo New, vamos criar agora um Web Service.
#
# ![image.png](data:image/png;base64,...)
#
# Aqui, podemos agora linkar com o respositório que acabamos de subir, que é o nosso projeto.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# Aqui é o primeiro processo que podemos melhorar na nossa aplicação, vamos voltar agora no nosso VSCODE e melhorar adicionando um requirements.txt

# %% [markdown]
# No seu terminal, depois de entrar no .venv, você vai passar o seguinte comando
#
# pip freeze > requirements.txt
#
# Isso vai criar um arquivo com todas as nossas dependências para usar nossa aplicação.

# %% [markdown]
# Depois disso, você pode subir sua aplicação mais uma vez, para atualizar no github.
#
# git add .
#
# git commit -m "Add nova mudança"
#
# git push -u origin main

# %% [markdown]
# Agora, dentro do render, só precisamos executar mais um processo, somente adicionar o comando que nosso servidor vai rodar na pasta

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Isso já o suficiente para nossa aplicação rodar?
#
# Sim
#
# Porém, concorda comigo que a aplicação não está conectada com o banco que criamos?
#
# Então, precisamos fazer essa conexão

# %% [markdown]
# Para isso, vamos precisar fazer mais algumas alterações no nosso projeto, por isso, vamos voltar ao VSCODE.

# %% [markdown]
# Precisamos fazer a instalação do psycopg

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Com isso vamos utilizar esses dois comandos que estão sinalizados acima

# %% [markdown]
# Certo, agora, vamos fazer o processo de deploy da nossa aplicação, para verificarmos se vai funcionar mesmo com o nosso SQLite, para isso, depois de preencher todos os campos, vamos colocar que queremos utilizar a versão free e lá no final clicar em **Deploy**, com isso, entraremos em uma tela de carregamento onde nossa aplicação estará sendo buildada para efetuar o deploy.
#
# ![image.png](data:image/png;base64,...)
#
# Quando aparecer um campo escrito Live, na cor verde, significa que sua aplicação poderá ser acessada de qualquer lugar com internet

# %% [markdown]
# Feito tudo isso, sua aplicação deve estar rodando certinho, agora, basta testar suas rotas de usuário.

# %% [markdown]
# Se estiver tudo certo, agora, precisamos apenas conectar somente ao banco que subimos no render.
#
# Para isso precisamos alterar no nosso código mesmo e subir novamente para o GitHub.

# %% [markdown]
# Agora, no arquivo de _session.py_, você vai adicionar o seguinte código:
#
#
#
# ```
# from sqlalchemy import create_engine
# from sqlalchemy.orm import sessionmaker, declarative_base
# import os
#
#
# DATABASE_URL = os.getenv('db_uri')
#
# engine = create_engine(
#     DATABASE_URL
# )
#
# SessionLocal = sessionmaker(
#     bind=engine,
#     autocommit=False,
#     autoflush=False
# )
#
# Base = declarative_base()
#
# ```

# %% [markdown]
# A biblioteca os fica responsável por buscar nosso enviroment que criamos no começo, chamado db_uri.

# %% [markdown]
# Agora, basta subirmos novamente o nosso código e vai funcionar normalmente.

# %% [markdown]
# Bom, chegamos ao fim da nossa aula e do nosso Super módulo, espero que tenham curtido nossas aulas e vou deixar alguns conteúdos para vocês continuarem os seus estudos.
#
# Antes disso, segue o QR Code para a pesquisa de satisfação:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Próximos estudos:
#
# Para apronfundar mais ainda sobre API's, estude:
#
# - Autenticação e autorização de API's, JWT.
#
# Para deixar seu processo de deploy melhor e mais robusto:
#
# - Estude docker e linux, a maioria dos servidores do mundo são Linux.
#
# Aprofunde seus estudos sobre modelagem de sistema:
#
# - A parte de modelagem de sistemas é muito importante para que o sistema tenha performance e seja eficiente.

# %% [markdown]
# ###Extra:
#
# Pensando nos alunos em geral, criei uma biblioteca Python para ajudar vocês criar arquiteturas de maneira mais simples e fácil, apenas com essa biblioteca, abaixo você vai ter o link da documentação e de como instalar essa ferramenta na máquina de vocês:
#
# https://github.com/FelipeHardmann/fast_hard
#
# https://pypi.org/project/fast-hard/
#
# Essa ferramenta não é interessante quando estamos falando de programas rodando em produção, qualquer ferramente a mais pode pesar seu programa, mas, pode te ajudar bastante a entender alguns padrões de projeto, dê uma estrela nesse repositório e no da aula para ajudar seu professor 🍻.
