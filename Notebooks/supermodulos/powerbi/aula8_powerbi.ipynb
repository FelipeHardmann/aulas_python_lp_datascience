# %% [markdown]
# #Bem-vindo a última aula do Super módulo de Power BI
#
# Na aula de hoje vamos fazer um dashboard baseado em dados da amazon.
#
# O link do dataset está no mesmo local da base de dados das outras aulas.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A atividade de hoje, mais uma vez, vocês vão trabalhar sozinhos nela, com o intuito de entregar o projeto em 1 hora com o dashboard completo.
