# %% [markdown]
# ### O que isso realmente significa para a nossa profissão?
#
# O Vibe Coding, ou a programação assistida por IA, representa uma mudança significativa. Em vez de substituir programadores, a intenção é **aumentar a produtividade** e **democratizar o desenvolvimento de software**.  Significa que a programação pode se tornar mais acessível a pessoas com menos experiência formal em codificação, e os desenvolvedores existentes poderão focar em problemas mais complexos, design de arquitetura e otimização, em vez de tarefas repetitivas de codificação.
#
# ### Como usar o Vibe Coding?
#
# Para usar o Vibe Coding efetivamente, é crucial desenvolver algumas habilidades:
#
# 1.  **"Prompt Engineering"**: A capacidade de articular claramente o que você quer que a IA faça. Isso envolve ser preciso, contextual e iterativo em seus pedidos.
# 2.  **Revisão Crítica**: A IA gera sugestões, mas a responsabilidade pela qualidade, segurança e otimização do código ainda recai sobre o desenvolvedor. É essencial revisar e entender o código gerado.
# 3.  **Conhecimento Fundacional**: Mesmo com a ajuda da IA, um bom entendimento dos princípios de programação, algoritmos e estruturas de dados é fundamental para guiar a IA e corrigir erros.
# 4.  **Integração**: Saber integrar ferramentas de IA ao seu fluxo de trabalho (como IDEs e sistemas de controle de versão).
#
# ### Ele é um hype passageiro ou o novo normal?
#
# É provável que o Vibe Coding não seja um hype passageiro, mas sim **parte do novo normal** no desenvolvimento de software. A capacidade de gerar código rapidamente e automatizar tarefas repetitivas oferece ganhos de produtividade inegáveis. No entanto, a forma como se integra e evolui ainda está em desenvolvimento. A IA continuará a melhorar, tornando-se uma ferramenta cada vez mais indispensável.
#
# ### Como podemos nos preparar para essa transformação?
#
# Para se preparar para essa transformação, os profissionais de desenvolvimento devem:
#
# 1.  **Adotar e Experimentar**: Começar a usar ferramentas de Vibe Coding (como GitHub Copilot, Cursor, etc.) para entender seus pontos fortes e fracos.
# 2.  **Aprimorar Habilidades de "Prompt Engineering"**: Aprender a se comunicar eficazmente com a IA para obter os melhores resultados.
# 3.  **Focar em Habilidades "Humanas"**: Pensamento crítico, resolução de problemas complexos, design de sistemas, comunicação e colaboração se tornarão ainda mais valiosos.
# 4.  **Manter-se Atualizado**: Acompanhar as inovações em IA e ferramentas de desenvolvimento.
# 5.  **Entender os Fundamentos**: Reforçar o conhecimento dos fundamentos de programação, que são a base para qualquer código, gerado por IA ou não.
#
# **Em resumo, o Vibe Coding é uma ferramenta poderosa que está mudando o cenário do desenvolvimento. Aqueles que souberem alavancar a IA de forma inteligente e manterem suas habilidades críticas afiadas estarão bem posicionados para prosperar neste novo ambiente.**

# %% [markdown]
# ![ChatGPT Image 31 de jan. de 2026, 12_50_43.png](data:image/png;base64,...\...)Bom

# %% [markdown]
# ##Nem tudo são nuvens
#
# Bom, com o crescimento desse estilo de codificação, também vem o embate de opiniões, muitas pessoas estão utilizando o vibe coding, porém, muitas pessoas também não são a favor do desenvolvimento dessa maneira, agora vamos entender o por quê desses embates
#
# Bom, a questão que é muito conflituosa, não é o uso de IA no desenvolvimento ou não, mas sim, a codificação feita de forma que quem está por trás do sistema não entende o básico, conceitos básicos e muitas vezes conceito mais avançados que a IA não pode fazer
#
# _Exemplo_: Se você contratado por uma fintech grande, onde há uma volumetria de dados muito grande, como você iria arquitetar esse sistema?
#
# Bom, essa é uma questão que por exemplo, necessita de um conhecimento mais avançado, onde a pessoa precisa não somente orquestrar o código, mas também arquitetar esse sistema, precisa entender de SQL, NoSQL, Cache, ACID, processamento de linguagem, Cloud, entre diversos outros tópicos

# %% [markdown]
# Mas, em contra partida, temos o fato de que, o vibe coding acelera o desenvolvimento absurdamente, por isso ele é tão usado e vai permanecer no mercado
