# %% [markdown]
# # Workshop de Git GitHub

# %% [markdown]
# ### **Resumo sobre Git e GitHub**
#
# #### **O que é Git?**
# - **Criado por:** Linus Torvalds (o mesmo criador do Linux) em **2005**.
# - **Motivo da criação:** Necessidade de um sistema de controle de versão **rápido, eficiente e distribuído** para o desenvolvimento do kernel Linux, já que as ferramentas existentes (como CVS e Subversion) eram lentas e centralizadas.
# - **Por que existe?**
#   - Permite que vários desenvolvedores trabalhem no mesmo projeto **sem sobrescrever alterações**.
#   - Mantém um **histórico completo** de todas as mudanças no código.
#   - Facilita a **colaboração descentralizada** (cada pessoa tem uma cópia local do projeto).
#
# ---
#
# #### **O que é GitHub?**
# - **Criado por:** Chris Wanstrath, Tom Preston-Werner e PJ Hyett em **2008**.
# - **Motivo da criação:** Oferecer uma plataforma **baseada em nuvem** para hospedar repositórios Git, facilitando o compartilhamento e a colaboração em projetos open source e privados.
# - **Por que existe?**
#   - Fornece uma **interface gráfica** para gerenciar repositórios Git.
#   - Facilita **trabalho em equipe** com funcionalidades como *pull requests*, *issues* e *code review*.
#   - Tornou-se o **maior host de código-fonte do mundo**, servindo como portfólio para desenvolvedores e empresas.
#
# ---
#
# #### **Diferença entre Git e GitHub**
# | **Git** | **GitHub** |
# |---------|------------|
# | Ferramenta de **controle de versão local** | Plataforma **online** que usa Git |
# | Roda na sua máquina | Hospeda repositórios na nuvem |
# | Open source e gratuito | Gratuito para projetos públicos, pago para privados |
#
# ---
#
# #### **Por que são importantes?**
# - **Git:** Fundamental para **versionamento de código**, evitando conflitos e perdendo trabalho.
# - **GitHub:** Padrão da indústria para **colaboração em projetos**, integração contínua (CI/CD) e portfólio de desenvolvedores.
#
# Ambos revolucionaram o desenvolvimento de software, especialmente na cultura **open source**. 🚀

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ###Como funciona o Git?
#
# Mas como será que o Git guarda todas essas informações?
#
# Todos os nossos arquivos, assim como seus históricos, ficam em um repositório e existiam vários sistemas que gerenciam repositórios assim, como CVS (Sistema de Versões Concorrentes) e SVN (Subversion do Apache).
#
# O Git é uma alternativa com um funcionamento mais interessante ainda: ele é distribuído e todo mundo tem uma cópia inteira do repositório, não apenas o "servidor principal".
#
# E uma das vantagens disso é que cada pessoa pode desenvolver offline, realizando seus commits e outras operações sem depender de uma conexão constante com o servidor principal.
#
# Mas…o que é a ferramenta Git exatamente?
#
# O Git é um sistema de controle de versão distribuído e amplamente adotado. O Git nasceu e foi tomando espaço dos outros sistemas de controle.

# %% [markdown]
# No mundo corporativo não existe apenas o GitHub, existe o GitLab, Bitbucket.

# %% [markdown]
# ###Como baixar e instalar o Git?
#
# Para utilizar o Git, você pode seguir esse passo a passo de como fazer o download e instalar, para cada sistema operacional:
#
# Windows:
#
#     Acesse o site oficial do Git em "https://git-scm.com/download/win".
#     Clique no link para download do Git para Windows.
#     Após o download, execute o instalador.
#     Siga as instruções do instalador, aceitando as configurações padrão, se não for um usuário avançado.
#     Conclua a instalação.
#
# Linux:
#
#     No Linux, você pode instalar o Git usando o gerenciador de pacotes da sua distribuição. Por exemplo, no Ubuntu,
#     use o comando sudo apt-get install git.
#     Se estiver usando outra distribuição, substitua o comando de acordo.
#
# macOS:
#
#     No macOS, o Git pode ser instalado de várias maneiras, incluindo o uso do Xcode Command Line Tools, que geralmente já
#     está instalado no sistema.
#     Abra o Terminal e digite git --version para verificar se o Git está disponível.
#     Se não estiver, o sistema solicitará a instalação.
#     Siga as instruções para instalar o Git.
#     Com esses passos simples, você pode instalar o Git no seu sistema operacional e começar a usar
#     essa poderosa ferramenta de controle de versão.

# %% [markdown]
# Agora, podemos executar o Git no nosso terminal.
#
# **Primeiros passos:**
#
# ```
# git config --global user.name "Seu Nome"
# git config --global user.email "seu@email.com"
# ```
#
# Agora, vamos criar um repositório Git:
#
# ```
# git init
# ```
#
# Depois disso, vamos precisar linkar o repositório local com o virtual do GitHub:
#
# ```
# git remote add origin <link_do_repositorio>
# ```
#
# Agora, vamos criar a nossa branch que vai ser onde vai ficar o nosso repositório:
#
# ```
# git checkout -b main
# ```
#
# Adicione Arquivos ao Controle de Versão:
#
# Use o comando git add para adicionar arquivos ao "staging area", que é onde você prepara os arquivos para serem “commitados” ou salvos.
#
# ```
# git add nome-do-arquivo
# ```
#
# Agora, vamos fazer um *commit*
#
# Um commit é um snapshot de suas alterações. Use o comando git commit para criar um commit com uma mensagem descritiva do que foi alterado no projeto.
#
# ```
# git commit -m "Sua mensagem de commit aqui"
# ```
#
# E por fim precisamos subir o código
#
# ```
# git push -u origin main
# ```

# %% [markdown]
# Agora, estamos subindo um código no nosso repositório online no GitHub

# %% [markdown]
# Benefícios de Ter um GitHub
#
# O GitHub é muito mais do que um simples repositório de código. Ele é uma ferramenta essencial para desenvolvedores, empresas e entusiastas de tecnologia. Aqui estão os principais benefícios de usá-lo:
# 1. Controle de Versão Eficiente
#
# ✅ Git integrado: O GitHub é baseado no Git, permitindo:
#
#     Histórico completo de alterações.
#
#     Facilidade para voltar a versões anteriores.
#
#     Ramificação (branching) para trabalhar em features separadas.
#
# 2. Colaboração em Equipe
#
# 👥 Trabalho conjunto simplificado:
#
#     Pull Requests: Permite revisão de código antes de integrar mudanças.
#
#     Issues: Rastreamento de bugs, tarefas e melhorias.
#
#     Projetos (Boards): Organização estilo Kanban para gerenciar tarefas.
#
# 3. Portfólio Público para Devs
#
# 📂 Mostre seu trabalho:
#
#     Perfil com repositórios públicos serve como currículo digital.
#
#     Recrutadores e empresas analisam GitHub para avaliar habilidades.
#
#     Contribuições em open source aumentam sua visibilidade.
#
# 4. Hospedagem Gratuita para Projetos
#
# 🚀 Repositórios ilimitados (públicos):
#
#     Ideal para projetos pessoais, open source e testes.
#
#     GitHub Pages: Hospedagem grátis para sites estáticos (HTML, CSS, JS).
#
# 5. Integração com Ferramentas Dev
#
# 🔌 Ecossistema de integrações:
#
#     CI/CD (GitHub Actions): Automação de testes e deploys.
#
#     Conexão com VS Code, Docker, Slack, etc.
#
#     APIs para desenvolvimento de bots e ferramentas customizadas.
#
# 6. Aprendizado e Comunidade
#
# 🌍 Maior comunidade de devs do mundo:
#
#     Acesso a milhões de projetos open source.
#
#     Copiar, estudar e contribuir para códigos alheios.
#
#     Discussões e fóruns para tirar dúvidas.
#
# 7. Segurança e Backup
#
# 🔒 Proteção e redundância:
#
#     Código armazenado em nuvem (não se perde se o PC quebrar).
#
#     GitHub Copilot: IA para sugestões de código (assinatura paga).
#
#     Dependabot: Alerta sobre vulnerabilidades em dependências.
#
# 8. Networking e Oportunidades
#
# 💼 Conexões profissionais:
#
#     Empresas como Google, Microsoft e startups recrutam via GitHub.
#
#     Eventos (GitHub Universe) e programas para devs.
#
# Resumo: Por Que Usar GitHub?
# Vantagem	Impacto
# Versionamento	Nunca perca código e trabalhe em equipe sem conflitos.
# Portfólio	Mostre suas habilidades e atraia empregadores.
# Open Source	Contribua para projetos globais e aprenda com outros.
# Automação	CI/CD, deploys automáticos e integração com ferramentas.
# Comunidade	Acesso a tutoriais, soluções prontas e networking.
#
# Se você é dev, não ter um GitHub é como um escritor não ter um blog – você está desperdiçando oportunidades! 🌟
