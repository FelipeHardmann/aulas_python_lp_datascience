# %% [markdown]
# # Planilhas Amaldiçoadas
# ## Transforme planilhas “mortas” em análises vivas com Python e Pandas, despertando inteligência onde só havia números.

# %% [markdown]
# ### Introdução
#
# *Toda empresa possui uma planilha amaldiçoada*
#
# Na frase acima, estamos falando de algo que é muito comum no mundo corporativo, onde temos uma planilha que foi montado por uma pessoa a 10 anos atrás e continua da mesma forma, seguindo o mesmo padrão, pois ninguém consegue ver um futuro sem aquela planilha daquela forma, hoje, vamos aprender como manipular algumas planilhas com Python.

# %% [markdown]
# ### Por que utilizar Python para esse serviço se temos o Excel?
#
# Esse é um ótimo questionamento, o excel é uma ferramenta muito poderosa e cheia de benefícios, porém o Python trás também diversas vantagens sobre o Excel, são elas:
#
# - 1 - Economia de tempo, essa economia é bastante útil quando vamos trabalhar com um volume muito grande de dados ou até mesmo manipulações mais complexas.
# - 2 - Acertividade, quando utilizamos o Python para manipulação das planilhas, reduzimos muito os erros humanos que podem acontecer.
# - Flexibilidade, o Python, por ser uma linguagem de programação, possui uma flexibilidade maior, poderíamos por exemplo criar uma lógica para enviar os dados dessa planilha através de uma API.

# %% [markdown]
# Com o Excel tão monstruoso que temos nos dias de hoje, fica difícil visualizar um mundo onde o Python substituiria o Excel, porém, nesse caso de manipulações de planilhas não vamos utilizar apenas o Python, vamos utilizar a biblioteca mais famosa dele para a área de análise de dados, o **_PANDAS_**.

# %% [markdown]
# ##🐼 O que é o Pandas e por que ele é tão poderoso?
#
# O Pandas é uma das bibliotecas mais populares e essenciais do ecossistema Python para análise, limpeza e transformação de dados.
# Seu nome vem de “Panel Data”, um termo usado em estatística e econometria para se referir a conjuntos de dados estruturados em linhas e colunas — justamente o formato de planilhas com o qual estamos acostumados no Excel.
#
# A grande diferença é que, com o Pandas, essas planilhas ganham superpoderes: em vez de depender de cliques manuais, fórmulas confusas e macros frágeis, você usa código simples e reprodutível para automatizar e padronizar tarefas que antes levavam horas.
#
# ------------------------------------------------------------------------------
# ###🧠 Por que usar Pandas em vez de apenas Excel?
#
# O Excel é excelente para visualização e manipulação rápida de pequenas planilhas, mas ele não foi feito para lidar com automação, grandes volumes de dados ou análises complexas.
# Já o Pandas foi projetado desde o início para lidar com dados de forma programática, permitindo:
#
# Automatizar tarefas repetitivas (como limpeza e formatação de planilhas);
#
# Reproduzir análises com exatidão, sem depender de cliques manuais;
#
# Trabalhar com grandes volumes de dados, muito além do limite do Excel;
#
# Integrar facilmente com outras ferramentas do ecossistema de dados (SQL, APIs, scikit-learn, matplotlib, etc.);
#
# Transformar planilhas “mortas” em análises vivas e dinâmicas.
#
# ###⚙️ O que o Pandas faz de forma prática
#
# O Pandas é como uma ferramenta de transformação que pode ler, modificar e exportar dados em diversos formatos, como:
#
# - Excel (.xls, .xlsx)
#
# - CSV
#
# - JSON
#
# - SQL
#
# - Parquet
#
# - APIs e Web Scraping
#
# E ele não se limita a apenas “ler planilhas”

# %% [markdown]
# ##Primeiros passos com Pandas
#
# Para iniciarmos com o mundo de dados com Python, é ideal algumas coisas específicas, nesse caso, você pode utilizar o Google Colab, o Jupyter notebook ou DataBricks.

# %% [markdown]
# Para a aula de hoje, vamos utilizar o Jupyter.
#
# Com isso, na aula de hoje, vamos precisar fazer a instalação dele e de mais algumas bibliotecas, então, no seu terminal, copie e cole o seguinte:
#
# **Windows**
#
# python -m venv venv
# venv\Scripts\activate
#
# **Linux/Mac**
#
# python3 -m venv venv
# source venv/bin/activate
#
# -----------------------------------------------------------------------------
#
# Logo depois, vamos passar o seguinte comando
#
# ```
# pip install jupyter pandas numpy matplotlib openpyxl xlrd xlwt XlsxWriter
# ```
#
# Com isso, teremos instalado todas as dependências que usaremos nesse WorkShop.

# %% [markdown]
# Agora, precisamos iniciar nosso jupyter notebook, no seu terminal, passe o seguinte comando
#
# ```
# jupyter notebook
# ```

# %% [markdown]
# Nessa aula, usaremos o seguinte modelo:
#
# [Modelo](https://dq-blog-files.s3.amazonaws.com/movies.xls)
#
# Essa é um arquivo excel que possui 3 planilhas, cada folha delas tem dados sobre filmes.
#
# Usaremos esses dados para classificar os filmes, visualizar as classificações mai altas, ganhos líquidos, calcular informações estatísticas e etc.

# %% [markdown]
# ####Primeiros passos

# %%
import pandas as pd

# %% [markdown]
# Começamos importando o pandas ao nosso projeto para utilizarmos as funções que vem com a biblioteca

# %% [markdown]
# Em seguida, vamos ler os dados dentro desse arquivo com a função read_excel.

# %%
excel_file = 'movies.xls'
movies = pd.read_excel(excel_file)

# %% [markdown]
# Atribuímos o read_excel a variável movies, pois agora essa variável se torna um DataFrame, que é um objeto padrão do pandas.

# %%
print(movies)
# Out:
#                                                   Title  Year  \
# 0     Intolerance: Love's Struggle Throughout the Ages   1916
# 1                       Over the Hill to the Poorhouse   1920
# 2                                       The Big Parade   1925
# 3                                           Metropolis   1927
# 4                                        Pandora's Box   1929
# ...                                                 ...   ...
# 1333                                  Twin Falls Idaho   1999
# 1334                     Universal Soldier: The Return   1999
# 1335                                     Varsity Blues   1999
# 1336                                    Wild Wild West   1999
# 1337                                    Wing Commander   1999
#
#                             Genres Language  Country Content Rating  Duration  \
# 0                Drama|History|War      NaN      USA      Not Rated       123
# ...

# %% [markdown]
# Podemos visualizar as primeiras linhas de uma maneira melhor, que é com a função própria do pandas chamada de head, para visualizar as primeiras linhas do nosso DataFrame.

# %%
movies.head()
# Out:
#                                                Title  Year  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916
# 1                    Over the Hill to the Poorhouse   1920
# 2                                    The Big Parade   1925
# 3                                        Metropolis   1927
# 4                                     Pandora's Box   1929
#
#                 Genres Language  Country Content Rating  Duration  \
# 0    Drama|History|War      NaN      USA      Not Rated       123
# 1          Crime|Drama      NaN      USA            NaN       110
# 2    Drama|Romance|War      NaN      USA      Not Rated       151
# 3         Drama|Sci-Fi   German  Germany      Not Rated       145
# 4  Crime|Drama|Romance   German  Germany      Not Rated       110
#
#    Aspect Ratio     Budget  Gross Earnings  ... Facebook Likes - Actor 1  \
# 0          1.33   385907.0             NaN  ...                      436
# ...

# %% [markdown]
# Agora, conseguimos ver as primeiras linhas do nosso DataFrame.
#
# Agora, temos uma observação, o arquivo excel normalmente pode ter várias planilhas dentro dele, como é o caso do nosso, com isso é interessante que passemos a informação de qual planilha vamos ler esse arquivo, com isso, vamos modificar nossa função read_excel, que possui mais paramêtros para utilizar.

# %%
movies_sheet1 = pd.read_excel(excel_file, sheet_name=0, index_col=0)
movies_sheet1.head()
# Out:
#                                                    Year               Genres  \
# Title
# Intolerance: Love's Struggle Throughout the Ages   1916    Drama|History|War
# Over the Hill to the Poorhouse                     1920          Crime|Drama
# The Big Parade                                     1925    Drama|Romance|War
# Metropolis                                         1927         Drama|Sci-Fi
# Pandora's Box                                      1929  Crime|Drama|Romance
#
#                                                   Language  Country  \
# Title
# Intolerance: Love's Struggle Throughout the Ages       NaN      USA
# Over the Hill to the Poorhouse                         NaN      USA
# The Big Parade                                         NaN      USA
# Metropolis                                          German  Germany
# Pandora's Box                                       German  Germany
#
#                                                   Content Rating  Duration  \
# ...

# %% [markdown]
# Agora, se quisermos ler a outra planilha, basta modificarmos o sheet_name

# %%
movies_sheet2 = pd.read_excel(excel_file, sheet_name=1, index_col=0)
movies_sheet2.head()
# Out:
#                         Year                   Genres Language Country  \
# Title
# 102 Dalmatians          2000  Adventure|Comedy|Family  English     USA
# 28 Days                 2000             Comedy|Drama  English     USA
# 3 Strikes               2000                   Comedy  English     USA
# Aberdeen                2000                    Drama  English      UK
# All the Pretty Horses   2000    Drama|Romance|Western  English     USA
#
#                        Content Rating  Duration  Aspect Ratio      Budget  \
# Title
# 102 Dalmatians                      G     100.0          1.85  85000000.0
# 28 Days                         PG-13     103.0          1.37  43000000.0
# 3 Strikes                           R      82.0          1.85   6000000.0
# Aberdeen                          NaN     106.0          1.85   6500000.0
# All the Pretty Horses           PG-13     220.0          2.35  57000000.0
#
#                         Gross Earnings            Director  ...  \
# ...

# %% [markdown]
# E a mesma coisa fazemos com a terceira planilha

# %%
movies_sheet3 = pd.read_excel(excel_file, sheet_name=2, index_col=0)
movies_sheet3.head()
# Out:
#                                         Year  \
# Title
# 127 Hours                             2010.0
# 3 Backyards                           2010.0
# 3                                     2010.0
# 8: The Mormon Proposition             2010.0
# A Turtle's Tale: Sammy's Adventures   2010.0
#
#                                                                   Genres  \
# Title
# 127 Hours                             Adventure|Biography|Drama|Thriller
# 3 Backyards                                                        Drama
# 3                                                   Comedy|Drama|Romance
# 8: The Mormon Proposition                                    Documentary
# A Turtle's Tale: Sammy's Adventures           Adventure|Animation|Family
#
#                                      Language  Country Content Rating  \
# Title
# 127 Hours                             English      USA              R
# 3 Backyards                           English      USA              R
# ...

# %% [markdown]
# Agora, temos a visualização de todos os dados das três planilhas.
#
# Tem uma observação muito interessante nessas três planilhas, elas possuem as mesmas colunas, o mesmo formato, logo, podemos transformar todas elas em uma única planilha, da seguinte forma

# %%
movies = pd.concat([movies_sheet1, movies_sheet2, movies_sheet3])

# %% [markdown]
# Com o método concat, fazemos uma concatenação das planilhas, agora temos um DataFrame maior, com todos os dados juntos.

# %%
movies.shape
# Out:
# (5042, 24)

# %% [markdown]
# Essas são a quantidade de linhas e colunas que temos no nosso DataFrame

# %% [markdown]
# Usamos o head() para visualizar as linhas superiores, mas também podemos usar o método tail() para visualizar as inferiores.

# %%
movies.tail()
# Out:
#                                       Year  \
# Title
# War & Peace                            NaN
# Wings                                  NaN
# Wolf Creek                             NaN
# Wuthering Heights                      NaN
# Yu-Gi-Oh! Duel Monsters                NaN
#
#                                                                          Genres  \
# Title
# War & Peace                                           Drama|History|Romance|War
# Wings                                                              Comedy|Drama
# Wolf Creek                                                Drama|Horror|Thriller
# Wuthering Heights                                                 Drama|Romance
# Yu-Gi-Oh! Duel Monsters               Action|Adventure|Animation|Family|Fantasy
#
#                                       Language    Country Content Rating  \
# Title
# War & Peace                            English         UK          TV-14
# ...

# %% [markdown]
# No Excel podemos classificar valores de uma planilha se baseando em uma coluna ou mais, no pandas também podemos fazer isso da seguinte maneira

# %%
sorted_by_gross = movies.sort_values(['Gross Earnings'], ascending=False)

# %%
sorted_by_gross["Gross Earnings"].head(10)
# Out:
# Title
# Avatar                                        760505847.0
# Titanic                                       658672302.0
# Jurassic World                                652177271.0
# The Avengers                                  623279547.0
# The Avengers                                  623279547.0
# The Dark Knight                               533316061.0
# Star Wars: Episode I - The Phantom Menace     474544677.0
# Star Wars: Episode IV - A New Hope            460935665.0
# Avengers: Age of Ultron                       458991599.0
# The Dark Knight Rises                         448130642.0
# Name: Gross Earnings, dtype: float64

# %% [markdown]
# Agora temos, do filme que tem o maior lucro para o menor

# %% [markdown]
# Também, com a utilização do Pandas podemos criar gráficos para visualizar a classificação dos filmes que tiveram o maior lucro bruto, para isso, vamos utilizar além do pandas, vamos usar também a biblioteca chamada de matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Importado nossa biblioteca, agora vamos utilizar ela para exibir o nosso gráfico

# %%
sorted_by_gross['Gross Earnings'].head(10).plot(kind="barh")
plt.show()

# %% [markdown]
# Agora, conseguimos visualizar os filmes com maior lucro bruto de maneira visual atráves do matplot

# %% [markdown]
# Agora, vamos criar um histograma de pontuações do IMDB para verificar a distribuição de pontuações do IMDB em todos os filmes. Os histogramas são uma boa maneira de visualizar a distribuição de um conjunto de dados.

# %%
movies['IMDB Score'].plot(kind="hist")
plt.show()

# %% [markdown]
# Também podemos usar funções para visualizar informações estatísticas da nossa planilha

# %%
movies.describe()
# Out:
#               Year     Duration  Aspect Ratio        Budget  Gross Earnings  \
# count  4935.000000  5028.000000   4714.000000  4.551000e+03    4.159000e+03
# mean   2002.470517   107.201074      2.220403  3.975262e+07    4.846841e+07
# std      12.474599    25.197441      1.385113  2.061149e+08    6.845299e+07
# min    1916.000000     7.000000      1.180000  2.180000e+02    1.620000e+02
# 25%    1999.000000    93.000000      1.850000  6.000000e+06    5.340988e+06
# 50%    2005.000000   103.000000      2.350000  2.000000e+07    2.551750e+07
# 75%    2011.000000   118.000000      2.350000  4.500000e+07    6.230944e+07
# max    2016.000000   511.000000     16.000000  1.221550e+10    7.605058e+08
#
#        Facebook Likes - Director  Facebook Likes - Actor 1  \
# count                4938.000000               5035.000000
# mean                  686.621709               6561.323932
# std                  2813.602405              15021.977635
# ...

# %% [markdown]
# A função describe possui muitas informações, que são elas:
#
# - Contagem de valores
# - Média
# - Desvio Padrão
# - Minimo
# - 25%
# - 50%
# - 75%
# - Máximo

# %% [markdown]
# Mas, em alguns casos não precisamos ver as informações de todas as colunas, para isso, podemos verificar as informações de uma coluna específica, utilizando o método:
#
# mean()

# %%
movies["Gross Earnings"].mean()
# Out:
# np.float64(48468407.52680933)

# %% [markdown]
# Nesse caso acima, temos a médica de lucro bruto de todos os filmes
#
# Estamos vendo que o Pandas é muito poderoso para se trabalhar com Planilhas e juntamente com Excel, além dessas questões acima, também é possível dividirmos o nosso DataFrame e trabalharmos com subconjuntos de dados.
#
# Da seguinte maneira:

# %%
movies_subset_columns = pd.read_excel(excel_file, usecols=[0, 1, 2, 3, 4, 5, 6])
movies_subset_columns.head()
# Out:
#                                                Title  Year  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916
# 1                    Over the Hill to the Poorhouse   1920
# 2                                    The Big Parade   1925
# 3                                        Metropolis   1927
# 4                                     Pandora's Box   1929
#
#                 Genres Language  Country Content Rating  Duration
# 0    Drama|History|War      NaN      USA      Not Rated       123
# 1          Crime|Drama      NaN      USA            NaN       110
# 2    Drama|Romance|War      NaN      USA      Not Rated       151
# 3         Drama|Sci-Fi   German  Germany      Not Rated       145
# 4  Crime|Drama|Romance   German  Germany      Not Rated       110

# %% [markdown]
# Dessa maneira, dividimos o nosso DataFrame, agora, ao invés de utilizarmos as 25 colunas, estamos utilizando apenas 7 delas, isso por conta do paramêtro da função que é o usecols, nele informamos os indíces de cada de colunas que queremos usar, ou seja, um subconjunto de dados.

# %% [markdown]
# ### Aplicando fórmulas
#
# No Excel temos processos para aplicar fórmulas, para criar novas colunas a partir de algumas existente, podemos criar tabelas dinâmicas, etc.
#
# Com o Python e o Pandas também conseguimos aplicar essas modificaçoes, da seguinte maneira:
#
# Podemos obter por exemplo, uma nova coluna, dos ganhos líquidos subtraindo os ganhos brutos

# %%
movies["Net Earnings"] = movies["Gross Earnings"] - movies["Budget"]

# %%
movies["Net Earnings"]
# Out:
# Title
# Intolerance: Love's Struggle Throughout the Ages           NaN
# Over the Hill to the Poorhouse                       2900000.0
# The Big Parade                                             NaN
# Metropolis                                          -5973565.0
# Pandora's Box                                              NaN
#                                                        ...
# War & Peace                                                NaN
# Wings                                                      NaN
# Wolf Creek                                                 NaN
# Wuthering Heights                                          NaN
# Yu-Gi-Oh! Duel Monsters                                    NaN
# Name: Net Earnings, Length: 5042, dtype: float64

# %% [markdown]
# Que fica dessa maneira que vemos acima, mas, podemos fazer a modificação de visualização

# %%
sorted_movies = movies[['Net Earnings']].sort_values(['Net Earnings'], ascending=[False])
sorted_movies.head(10)['Net Earnings'].plot.barh()
plt.show()

# %% [markdown]
# Assim, dessa maneira, temos os filmes com o maior lucro líquido, visualmente, atráves de um gráfico.

# %% [markdown]
# Como foi dito acima, também é possível criarmos tabelas dinâmicas, que é algo até um pouco avançado no Excel, primeiro, precisamos identificar quais colunas servirão como índices, vamos por partes, vamos pegar o Ano e Ganhos Brutos

# %%
movies_subset = movies[['Year', 'Gross Earnings']]
movies_subset.head()
# Out:
#                                                      Year  Gross Earnings
# Title
# Intolerance: Love's Struggle Throughout the Ages   1916.0             NaN
# Over the Hill to the Poorhouse                     1920.0       3000000.0
# The Big Parade                                     1925.0             NaN
# Metropolis                                         1927.0         26435.0
# Pandora's Box                                      1929.0          9950.0

# %% [markdown]
# Agora ligamos pivot_tablesobre este subconjunto de dados. O método pivot_tableleva um parâmetro index. Como mencionado, queremos usar o Ano como o índice.

# %%
earnings_by_year = movies_subset.pivot_table(index=['Year'])
earnings_by_year.head()
# Out:
#         Gross Earnings
# Year
# 1920.0       3000000.0
# 1927.0         26435.0
# 1929.0       1408975.0
# 1933.0       2300000.0
# 1935.0       3000000.0

# %% [markdown]
# Isso acabou de nos dar uma tabela dinâmica, com o ano como índice da nossa tabela, agora, a partir dessa tabela dinâmica podemos usar esses dados para criar uma visualização gráfica, da seguinte maneira

# %%
earnings_by_year.plot()
plt.show()

# %% [markdown]
# Agora, vamos criar outro subconjunto DataFrame, mas desta vez vamos escolher as colunas, País, Idioma e Ganhos Brutos.

# %%
movies_subset = movies[['Country', 'Language', 'Gross Earnings']]
movies_subset.head()
# Out:
#                                                    Country Language  \
# Title
# Intolerance: Love's Struggle Throughout the Ages       USA      NaN
# Over the Hill to the Poorhouse                         USA      NaN
# The Big Parade                                         USA      NaN
# Metropolis                                         Germany   German
# Pandora's Box                                      Germany   German
#
#                                                    Gross Earnings
# Title
# Intolerance: Love's Struggle Throughout the Ages              NaN
# Over the Hill to the Poorhouse                          3000000.0
# The Big Parade                                                NaN
# Metropolis                                                26435.0
# Pandora's Box                                              9950.0

# %%
earnings_by_co_lang = movies_subset.pivot_table(index=['Country', 'Language'])
earnings_by_co_lang.head()
# Out:
#                         Gross Earnings
# Country     Language
# Afghanistan Dari          1.127331e+06
# Argentina   Spanish       7.230936e+06
# Aruba       English       1.007614e+07
# Australia   Aboriginal    6.165429e+06
#             Dzongkha      5.052950e+05

# %% [markdown]
# Agora, estamos utilizando as colunas país e idioma como índices da nossa tabela dinâmica, com isso, podemos criar também, mais visualizações gráficas

# %%
earnings_by_co_lang.head(20).plot(kind='bar', figsize=(20,8))
plt.show()

# %% [markdown]
# Por fim, com as alterações que fizemos, é sempre interessante que tenhamos o arquivo excel alterado em mãos, seja para passar para um outro colega ou gestor ou até mesmo só para ter o arquivo, com o Pandas podemos exportar esse arquivo excel da seguinte maneira

# %%
movies.to_excel('output.xlsx')

# %% [markdown]
# # Fim, espero que tenha curtido essa aula introdutória ao Python com Pandas
